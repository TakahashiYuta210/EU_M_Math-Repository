# %% [markdown]
# <a href="https://colab.research.google.com/github/TakahashiYuta210/EU_M_Math-Repository/blob/Chap07_Hw-01/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline
# %precision 3
# Out:
# '%.3f'

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /content/drive/MyDrive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd "/content/drive/My Drive/"
# Out:
# /content/drive/My Drive

# %%
input_book = pd.ExcelFile('report2-10 (修正)draft .xlsx')

# %%
df = pd.read_excel("report2-10 (修正)draft .xlsx", sheet_name=5,skiprows=1)
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         deg      金属板CL        理論値
# 1       -20.0  -0.405985  -1.088387
# 2       -15.0  -0.462804   -0.81629
# 3       -10.0  -0.396206  -0.544194
# 4        -5.0  -0.228973  -0.272097
# 5         0.0  -0.046973        0.0
# 6         5.0    0.16041   0.272097
# 7        10.0   0.411701   0.544194
# 8        15.0   0.701841    0.81629
# 9        20.0   0.838345   1.088387
# 10       25.0   0.946832   1.360484
# 11       30.0   1.052203   1.632581
# 12       35.0   1.113248   1.904678
# 13       40.0   1.195061   2.176775
# 14       45.0    1.28235   2.448871
# 15       50.0   1.350085   2.720968
# 16       55.0   1.393464   2.993065
# 17       60.0   1.368156   3.265162

# %%
import xlrd

# %%
wb = xlrd.open_workbook(r"C:\Users\tyann\OneDrive\デスクトップ\report2-10 (修正)draft.xlsx")
Sheet = wb.sheet_by_name('sheet_1')
Sheet_Max = Sheet.nrows
x = []
y_1 = []
y_2 = []
for i in range(1,Sheet_Max):

    x.append(int(Sheet.cell_value(i,0)))
    y_1.append(int(Sheet.cell_value(i,1)))
    y_2.append(int(Sheet.cell_valiue(i,2)))

print(x)
print(y_1)
print(y_2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-9972fb908c12> in <module>()
# ----> 1 wb = xlrd.open_workbook(r"C:\Users\tyann\OneDrive\デスクトップ\report2-10 (修正)draft.xlsx")
#       2 Sheet = wb.sheet_by_name('sheet_1')
#       3 Sheet_Max = Sheet.nrows
#       4 x = []
#       5 y_1 = []
#
# /usr/local/lib/python3.7/dist-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
#     118     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\tyann\\OneDrive\\デスクトップ\\report2-10 (修正)draft.xlsx'

# %%
df1 = pd.read_excel("report2-10 (修正)draft .xlsx", sheet_name=5,skiprows=1,usecols="A")
df1 = []
# Out:
#    Unnamed: 0
# 0         deg
# 1       -20.0
# 2       -15.0
# 3       -10.0
# 4        -5.0
# 5         0.0
# 6         5.0
# 7        10.0
# 8        15.0
# 9        20.0
# 10       25.0
# 11       30.0
# 12       35.0
# 13       40.0
# 14       45.0
# 15       50.0
# 16       55.0
# 17       60.0

# %%
x = [-20.0,-15.0,-10.0,-5.0,0.0,5.0,10.0,15.0,20.0,25.0,30.0,35.0,40.0,45.0,50.0,55.0,60.0]

# %%
df2 = pd.read_excel("report2-10 (修正)draft .xlsx", sheet_name=5,skiprows=1,usecols="B")
df2
# Out:
#    Unnamed: 1
# 0       金属板CL
# 1   -0.405985
# 2   -0.462804
# 3   -0.396206
# 4   -0.228973
# 5   -0.046973
# 6     0.16041
# 7    0.411701
# 8    0.701841
# 9    0.838345
# 10   0.946832
# 11   1.052203
# 12   1.113248
# 13   1.195061
# 14    1.28235
# 15   1.350085
# 16   1.393464
# 17   1.368156

# %%
y_1 = [-0.405985, -0.462804, -0.396206, -0.228973, -0.046973, 0.16041, 0.411701, 0.701841, 0.838345, 0.946832, 1.052203, 1.113248, 1.195061, 1.28235, 1.350085, 1.393464, 1.368156]

# %%
df3 = pd.read_excel("report2-10 (修正)draft .xlsx", sheet_name=5,skiprows=1,usecols="C")
df3
# Out:
#    Unnamed: 2
# 0         理論値
# 1   -1.088387
# 2    -0.81629
# 3   -0.544194
# 4   -0.272097
# 5         0.0
# 6    0.272097
# 7    0.544194
# 8     0.81629
# 9    1.088387
# 10   1.360484
# 11   1.632581
# 12   1.904678
# 13   2.176775
# 14   2.448871
# 15   2.720968
# 16   2.993065
# 17   3.265162

# %%
y_2 = [-1.088387, -0.81629, -0.544194, -0.272097, 0.0, 0.272097, 0.544194, 0.81629, 1.088387, 1.360484, 1.632581, 1.904678, 2.176775, 2.448871, 2.720968, 2.993065, 3.265162]

# %%
plt.scatter(x, y_1, color = 'red')
plt.scatter(x, y_2, color = 'blue')
plt.title("Lift coefficient")
plt.xlabel("deg")
plt.ylabel("CL")
plt.legend(["theoretical", "experiment"])
plt.grid(True)
