# %% [markdown]
# <a href="https://colab.research.google.com/github/TakahashiYuta210/EU_M_Math-Repository/blob/Chap02_Cm-02/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as randam
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
import numpy.random as random

# %%
N = 10000
x = np.random.uniform(0.0,1.0,N)
y = np.random.uniform(0.0,1.0,N)

point_in = 0
for point in range(0,N):
  l = np.math.hypot(x[point],y[point])
  if l < 1:
    point_in += 1

print("円の中の数:", point_in)
# Out:
# 円の中の数: 7890

# %%
#円の中のx,y
x_in = []
y_in = []
#円の中のx,y
x_out = []
y_out = []

plt.figure(figsize=(10,10))
cir_x = np.arange(0,1,0.01)
cir_y = np.sprt(1 - cir_x * cir_x)

for point in range(0,N):
  l = np.math.hypot(x[point],y[point])
  if l < 1:
    x_in.append(x[point])
    y_in.append(y[point])
  else:
    x_out.append(x[point])
    y_out.append(y[point])

plt.plot(cir_x,cir_y)
plt.scatter(x_in,y_in,color="k")
plt.scatter(x_in,y_in,color="w")
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5a2576c5a364> in <module>()
#       8 plt.figure(figsize=(10,10))
#       9 cir_x = np.arange(0,1,0.01)
# ---> 10 cir_y = np.sprt(1 - cir_x * cir_x)
#      11
#      12 for point in range(0,N):
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'sprt'

# %%
#円の中のx,y
x_in = []
y_in = []
#円の中のx,y
x_out = []
y_out = []

plt.figure(figsize=(10,10))
cir_x = np.arange(0,1,0.01)
cir_y = np.sqrt(1 - cir_x * cir_x)

for point in range(0,N):
  l = np.math.hypot(x[point],y[point])
  if l < 1:
    x_in.append(x[point])
    y_in.append(y[point])
  else:
    x_out.append(x[point])
    y_out.append(y[point])

plt.plot(cir_x,cir_y)
plt.scatter(x_in,y_in,color="k")
plt.scatter(x_in,y_in,color="w")
plt.grid(True)

# %%
#円の中のx,y
x_in = []
y_in = []
#円の中のx,y
x_out = []
y_out = []

plt.figure(figsize=(10,10))
cir_x = np.arange(0,1,0.01)
cir_y = np.sqrt(1 - cir_x * cir_x)

for point in range(0,N):
  l = np.math.hypot(x[point],y[point])
  if l < 1:
    x_in.append(x[point])
    y_in.append(y[point])
  else:
    x_out.append(x[point])
    y_out.append(y[point])

plt.plot(cir_x,cir_y)
plt.scatter(x_in,y_in,color="k")
plt.scatter(x_out,y_out,color="w")
plt.grid(True)
